# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../datasets/train_1st_clean.csv")
df.shape
# Out:
# (2051, 82)

# %%
kaggle_data = pd.read_csv('../datasets/test.csv')
kaggle_data.shape
# Out:
# (878, 80)

# %%
df.head()
# Out:
#    Unnamed: 0   id        pid  ms_subclass ms_zoning  lot_frontage  lot_area  \
# 0           0  109  533352170           60        RL           NaN     13517
# 1           1  544  531379050           60        RL          43.0     11492
# 2           2  153  535304180           20        RL          68.0      7922
# 3           3  318  916386060           60        RL          73.0      9802
# 4           4  255  906425045           50        RL          82.0     14235
#
#   street alley lot_shape  ... screen_porch pool_area pool_qc fence  \
# 0   Pave   NaN       IR1  ...            0         0     NaN   NaN
# 1   Pave   NaN       IR1  ...            0         0     NaN   NaN
# 2   Pave   NaN       Reg  ...            0         0     NaN   NaN
# 3   Pave   NaN       Reg  ...            0         0     NaN   NaN
# 4   Pave   NaN       IR1  ...            0         0     NaN   NaN
#
#   misc_feature misc_val mo_sold yr_sold sale_type  saleprice
# ...

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# ...

# %%
kaggle_data.columns = [col.replace(" ", "_").lower() for col in kaggle_data.columns]
kaggle_data.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   alley lot_shape land_contour  ... 3ssn_porch screen_porch pool_area pool_qc  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   fence misc_feature misc_val mo_sold  yr_sold  sale_type
# ...

# %% [markdown]
# # Need to make Dummy Location Info Columns, explatory info below

# %%
df['ms_zoning'].value_counts() # No NaN values
# Out:
# RL         1598
# RM          316
# FV          101
# C (all)      19
# RH           14
# A (agr)       2
# I (all)       1
# Name: ms_zoning, dtype: int64

# %%
df.groupby('ms_zoning')[['saleprice']].mean().sort_values('saleprice')
# Out:
#                saleprice
# ms_zoning
# A (agr)     47300.000000
# I (all)     57625.000000
# C (all)     78010.894737
# RM         129119.142405
# RH         148859.571429
# RL         191235.164581
# FV         218618.316832

# %%
df['lot_shape'].value_counts() # No NaN values
# Out:
# Reg    1295
# IR1     692
# IR2      55
# IR3       9
# Name: lot_shape, dtype: int64

# %%
df.groupby('lot_shape')[['saleprice']].mean().sort_values('saleprice')
# Out:
#                saleprice
# lot_shape
# Reg        162925.812355
# IR3        193182.222222
# IR1        211848.670520
# IR2        233954.745455

# %%
df['lot_config'].value_counts() # No NaN values
# Out:
# Inside     1503
# Corner      348
# CulDSac     131
# FR2          60
# FR3           9
# Name: lot_config, dtype: int64

# %%
df.groupby('lot_config')[['saleprice']].mean().sort_values('saleprice')
# Out:
#                 saleprice
# lot_config
# FR2         174703.600000
# Inside      177537.014637
# Corner      180629.591954
# FR3         198600.000000
# CulDSac     230744.358779

# %%
df['neighborhood'].value_counts() # No NaN values
# Out:
# NAmes      310
# CollgCr    180
# OldTown    163
# Edwards    143
# Somerst    130
# NridgHt    122
# Gilbert    116
# Sawyer     111
# NWAmes      87
# SawyerW     87
# Mitchel     82
# BrkSide     76
# Crawfor     71
# IDOTRR      69
# Timber      48
# NoRidge     48
# StoneBr     38
# SWISU       32
# ClearCr     27
# MeadowV     24
# Blmngtn     22
# BrDale      19
# NPkVill     17
# Veenker     17
# Blueste      6
# Greens       3
# GrnHill      2
# Landmrk      1
# Name: neighborhood, dtype: int64

# %%
df.groupby('neighborhood')[['saleprice']].mean().sort_values('saleprice')
# Out:
#                   saleprice
# neighborhood
# MeadowV       100231.250000
# IDOTRR        101103.188406
# BrDale        103371.052632
# OldTown       125276.300613
# BrkSide       127022.697368
# Edwards       130493.468531
# SWISU         134758.875000
# Landmrk       137000.000000
# Sawyer        137181.909910
# NPkVill       140476.470588
# Blueste       144566.666667
# NAmes         145905.816129
# Mitchel       167656.707317
# SawyerW       187760.160920
# Greens        188666.666667
# Gilbert       189228.387931
# NWAmes        194619.022989
# Blmngtn       200417.681818
# CollgCr       202497.216667
# Crawfor       205901.211268
# ClearCr       217490.074074
# Somerst       227183.900000
# Timber        241051.354167
# Veenker       253570.588235
# GrnHill       280000.000000
# NoRidge       316294.125000
# NridgHt       322831.352459
# StoneBr       329675.736842

# %%
df['house_style'].value_counts()
# Out:
# 1Story    1059
# 2Story     598
# 1.5Fin     218
# SLvl        94
# SFoyer      50
# 2.5Unf      14
# 1.5Unf      12
# 2.5Fin       6
# Name: house_style, dtype: int64

# %%
df.groupby('house_style')[['saleprice']].mean().sort_values('saleprice')
# Out:
#                  saleprice
# house_style
# 1.5Unf       112466.666667
# 1.5Fin       136480.091743
# SFoyer       149343.920000
# SLvl         166248.989362
# 1Story       179809.194523
# 2.5Unf       191785.714286
# 2Story       206408.963211
# 2.5Fin       243666.666667

# %% [markdown]
# # Largest range of prices in House Style, Neighborhood, Lot Shape, MS_Zoning

# %% [markdown]
# # Will create dummy columns for the above

# %%
pd.set_option('display.max_columns', 124)

# %%
df = pd.get_dummies(df, columns=['house_style', 'neighborhood', 'lot_shape', 'ms_zoning'])

# %%
df.head()
# Out:
#     id        pid  ms_subclass  lot_frontage  lot_area street alley  \
# 0  109  533352170           60           NaN     13517   Pave   NaN
# 1  544  531379050           60          43.0     11492   Pave   NaN
# 2  153  535304180           20          68.0      7922   Pave   NaN
# 3  318  916386060           60          73.0      9802   Pave   NaN
# 4  255  906425045           50          82.0     14235   Pave   NaN
#
#   land_contour utilities lot_config land_slope condition_1 condition_2  \
# 0          Lvl    AllPub    CulDSac        Gtl        RRAe        Norm
# 1          Lvl    AllPub    CulDSac        Gtl        Norm        Norm
# 2          Lvl    AllPub     Inside        Gtl        Norm        Norm
# 3          Lvl    AllPub     Inside        Gtl        Norm        Norm
# 4          Lvl    AllPub     Inside        Gtl        Norm        Norm
#
#   bldg_type  overall_qual  overall_cond  year_built  year_remod/add  \
# ...

# %%
features = ['totrms_abvgrd', 'mas_vnr_area', 'full_bath', 'year_remod/add', 
            'garage_yr_blt', 'year_built', '1st_flr_sf', 'total_bsmt_sf', 
            'garage_cars', 'garage_area', 'gr_liv_area', 'overall_qual', 
           'house_style_1.5Fin', 'house_style_1.5Unf', 'house_style_1Story', 
           'house_style_2.5Fin', 'house_style_2.5Unf', 'house_style_2Story', 
           'house_style_SFoyer', 'house_style_SLvl', 'neighborhood_Blmngtn', 
           'neighborhood_Blueste', 'neighborhood_BrDale', 'neighborhood_BrkSide', 
           'neighborhood_ClearCr', 'neighborhood_CollgCr', 'neighborhood_Crawfor', 
           'neighborhood_Edwards', 'neighborhood_Gilbert', 'neighborhood_Greens', 
            'neighborhood_IDOTRR', 
           'neighborhood_MeadowV', 'neighborhood_Mitchel', 'neighborhood_NAmes', 
           'neighborhood_NPkVill', 'neighborhood_NWAmes', 'neighborhood_NoRidge', 
            'neighborhood_NridgHt', 'neighborhood_OldTown', 'neighborhood_SWISU', 
           'neighborhood_Sawyer', 'neighborhood_SawyerW', 'neighborhood_Somerst', 
           'neighborhood_StoneBr', 'neighborhood_Timber', 'neighborhood_Veenker', 
           'lot_shape_IR1', 'lot_shape_IR2', 'lot_shape_IR3', 'lot_shape_Reg', 
           'ms_zoning_C (all)', 'ms_zoning_FV', 'ms_zoning_I (all)', 
           'ms_zoning_RH', 'ms_zoning_RL', 'ms_zoning_RM']

# Due to error, taking out neighborhood_landmark, neighborhood grnhill, ms zoning a (agr),

# %%
X = df[features]
y = df['saleprice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train), lr.score(X_test, y_test)
# Out:
# (0.8320696018010145, 0.8414494966538174)

# %%
cross_val_score(lr, X_train, y_train).mean()
# Out:
# 0.795144693696115

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.score(X, y)
# Out:
# 0.8378741870701724

# %%
lr.coef_
# Out:
# array([ 3.38772267e+01,  2.88882497e+01, -4.79463528e+03,  3.59684435e+02,
#        -1.40591368e+02,  2.93822497e+02, -9.97938312e+00,  1.52376379e+01,
#         4.12974718e+03,  3.29105816e+01,  6.12913452e+01,  1.57238924e+04,
#        -3.73055539e+03,  1.07585608e+04,  8.89100647e+03, -1.52375176e+04,
#        -5.99127549e+03, -1.07353574e+04,  1.38890676e+04,  2.15607105e+03,
#        -7.98557876e+04, -7.70071659e+04, -8.40785326e+04, -5.96173615e+04,
#        -4.81073282e+04, -6.96066841e+04, -4.40128754e+04, -7.61301285e+04,
#        -7.09981652e+04, -8.35111115e+04, -6.21796615e+04, -6.46159559e+04,
#        -7.07245253e+04, -7.18831743e+04, -8.40085247e+04, -7.80319883e+04,
#        -3.78251074e+04, -2.24822051e+04, -6.70652978e+04, -7.38443848e+04,
#        -7.15510691e+04, -7.63696550e+04, -6.26495259e+04, -9.62292916e+03,
#        -5.46053238e+04, -5.10805512e+04,  1.20709187e+04,  2.60041986e+04,
# ...

# %%
lr_coefs = pd.Series(lr.coef_, index=X.columns)

# %%
plt.figure(figsize=(8, 10))
lr_coefs[lr_coefs != 0].sort_values().plot.barh()
plt.title('Categorical Lin Reg Coefficients', size=15)
plt.xlabel('Coefficients', size=15)
plt.ylabel('Features', size=15);
plt.savefig('../visualizations/CategoricalLinRegCoefficients.png', bbox_inches='tight')

# %%
kaggle_data['mas_vnr_area'] = kaggle_data['mas_vnr_area'].fillna(round(kaggle_data['mas_vnr_area'].mean()))
kaggle_data['garage_yr_blt'] = kaggle_data['garage_yr_blt'].fillna(kaggle_data['year_built'])
kaggle_data['total_bsmt_sf'] = kaggle_data['total_bsmt_sf'].fillna(round(kaggle_data['total_bsmt_sf'].mean()))
kaggle_data['garage_cars'] = kaggle_data['garage_cars'].fillna(round(kaggle_data['garage_cars'].mean()))
kaggle_data['garage_area'] = kaggle_data['garage_area'].fillna(round(kaggle_data['garage_area'].mean()))

# %%
kaggle_data = pd.get_dummies(kaggle_data, columns=['house_style', 'neighborhood', 'lot_shape', 'ms_zoning'])

# %%
predictions = lr.predict(kaggle_data[features])

# %%
kaggle_data['saleprice'] = predictions

# %%
kaggle_lin1_locations =kaggle_data[['id', 'saleprice']]

# %%
kaggle_lin1_locations.to_csv('../datasets/Kaggle_mlr1_locations.csv', index=False)
